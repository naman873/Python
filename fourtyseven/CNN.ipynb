# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img=Image.open("../fifth/panda.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=306x164 at 0x25536F3B908>

# %%
##dir(img)

# %%
small=img.resize(size=(400,300))

# %%
img=np.array(small).mean(axis=2)

# %%
plt.imshow(img ,cmap="gray")

# %%
padded_img=np.pad(img,pad_width=1,mode='constant')

# %%
padded_img.shape
# Out:
# (302, 402)

# %%
plt.imshow(padded_img,cmap="gray")

# %%
fil=np.array([[1,1,1],[0,0,0],[-1,-1,-1]])

# %%
result=np.zeros_like(img)

# %%
for row in range(result.shape[0]):
    for col in range(result.shape[1]):
        cut=padded_img[row:row+3,col:col+3]
        result[row,col]=(cut * fil).mean()

# %%
plt.imshow(result,cmap="gray")

# %%
for row in range(result.shape[0]):
    for col in range(result.shape[1]):
        cut=padded_img[row:row+3,col:col+3]
        result[row,col]=abs((cut * fil).mean())

# %%
plt.imshow(result,cmap="gray")
