# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img=np.zeros((100,100,3),dtype=np.uint8)

# %%
plt.imshow(img)

# %%
img[:30,:,0]=255

# %%
plt.imshow(img)

# %%
img[30:60,:,1]=255

# %%
img[60:90,:,2]=255

# %%
plt.imshow(img)

# %%
img[90:,:,:1]=155

# %%
plt.imshow(img)

# %%
import PIL     #####library for mamage library

# %%
pan=PIL.Image.open("panda.jpg")

# %%
pan
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=306x164 at 0x2489BC15CF8>

# %%
type(pan)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
chacha=np.array(pan)

# %%
type(chacha)
# Out:
# numpy.ndarray

# %%
chacha.shape
# Out:
# (164, 306, 3)

# %%
chacha.size
# Out:
# 150552

# %%
chacha[:,:,0]=0

# %%
plt.imshow(chacha)

# %%
a=chacha[::2,::2].copy()

# %%
plt.imshow(a)

# %%
img=PIL.Image.fromarray(chacha)

# %%
f=open("mypanda.jpeg","wb")
img.save(f)
