# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL

# %%
alpha=PIL.Image.open("mustache.png")

# %%
alpha.size
# Out:
# (640, 320)

# %%
musth=np.array(alpha)

# %%
musth=musth[::4,::4]

# %%
musth.shape
# Out:
# (80, 160, 4)

# %%
ja=PIL.Image.open("Jamie_Before.jpg")

# %%
jamie=np.array(ja)

# %%
jamie.shape
# Out:
# (1024, 733, 3)

# %%
cut=jamie[550:-musth.shape[0]-330 , 300:musth.shape[1]+350]

# %%
plt.imshow(cut)

# %%
for row in range(musth.shape[0]):
    for col in range(musth.shape[1]):
        if musth[row, col,3]>100:
            cut[row,col]=musth[row,col,:3]

# %%
plt.imshow(jamie)

# %%
cut=jamie[550:-musth.shape[0]-250 , 250:musth.shape[1]+190]
