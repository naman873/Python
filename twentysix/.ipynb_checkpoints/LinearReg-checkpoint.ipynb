# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.linspace(-10,10,100)

# %%
y=np.abs(a)

# %%
plt.plot(a,y)

# %%
plt.plot(a,a**2)

# %%
## differtiate gives slopes 
## slope of a line remain same

# %%
x=np.linspace(-10,10,100)

# %%
m,c=5,50

# %%
noise=np.random.randint(-10,10,100)

# %%
y=m*x +c + noise

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
class Linearcoustom:
    
    def __init__(self,lr=.01,max_step=10):
        self.lr=lr
        self.max_step=max_step
    
    def fit(self,x,y):
        self.coef_=np.random.random()       ### it is m 
        
        for i in range(self.max_step):
            self.gradient_decent(x,y)
        
    def gradient_decent(self,x,y):
        delta_coef=self.gradient(x,y)
        print(delta_coef)
        self.coef_+=delta_coef
    
    def gradient(self,x,y):
        yp=self.predict(x)
        d_e2m=np.mean((yp-y)*x)
        
        return -d_e2m * self.lr
    
    def predict(self,x):
        return x*self.coef_

# %%
top=Linearcoustom()

# %%
top.fit(x,y)
# Out:
# 1.6328301925531574
# 1.0775579721899626
# 0.7111156988189652
# 0.469288474641472
# 0.30969879134588707
# 0.20438034715082104
# 0.13487726613320172
# 0.08900991300372896
# 0.05874054864892542
# 0.038764806515788966

# %%
top.coef_
# Out:
# 4.8775752269594586

# %%
plt.scatter(x,y)
plt.scatter(x,top.predict(x))

# %%
class Linearcoustom1:
    
    def __init__(self,lr=.01,max_step=10):
        self.lr=lr
        self.max_step=max_step
    
    def fit(self,x,y):
        self.coef_=np.random.random()       ### it is m 
        self.intercept_=np.random.random()
        
        for i in range(self.max_step):
            self.gradient_decent(x,y)
        
    def gradient_decent(self,x,y):
        delta_coef,delta_inter=self.gradient(x,y)
        print(delta_coef,delta_inter)
        self.coef_+=delta_coef
        self.intercept_+=delta_inter
        
    def gradient(self,x,y):
        yp=self.predict(x)
        d_e2m=np.mean((yp-y)*x)
        d_e2c=np.mean((yp-y))
        
        return -d_e2m * self.lr ,-d_e2c * self.lr
         
    
    def predict(self,x):
        return x*self.coef_+self.intercept_

# %%
top1=Linearcoustom1()

# %%
top.fit(x,y)
# Out:
# 1.4977305033126
# 0.9884012749133655
# 0.6522782824344096
# 0.4304597419432467
# 0.2840744424945334
# 0.187470002454305
# 0.12371757737725197
# 0.0816452699189946
# 0.05388038014856205
# 0.03555742258962342

# %%
top1.fit(x,y)
# Out:
# 1.517240011796395 0.4790726212988388
# 1.0012762367410553 0.47428189508585034
# 0.6607748902398883 0.46953907613499185
# 0.436066930932721 0.46484368537364196
# 0.28777480963910196 0.46019524851990556
# 0.18991199558674743 0.4555932960347065
# 0.12532912840068164 0.4510373630743593
# 0.08270878507250365 0.4465269894436159
# 0.05458222853269608 0.4420617195491796
# 0.03602059526063463 0.43764110235368786

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y)
plt.scatter(x,top1.predict(x))

# %%
import numpy as np

# %%
x=np.linspace(-100,100,100)
noise=np.random.randn(100)*1000
y=(x**2)+noise
x_mod=(x-np.mean(x))/np.std(x)
y_mod=-(y-np.mean(y))/(np.std(y))

# %%
plt.scatter(x_mod,y_mod)

# %%
#x=ax^2 + bx +c

# %%
class var:

    def __init__(self,lr=.01,maxstep=2000):
        self.lr=lr
        self.maxstep=maxstep
        
    def fit(self,x,y):
        self.a=np.random.random()
        self.b=np.random.random()
        self.c=np.random.random()
        
        for i in range(self.maxstep):
            self.grad(x,y)
            
    def grad(self,x,y):
        delta_a,delta_b,delta_c=self.gradient(x,y)
        self.a+=delta_a
        self.b+=delta_b
        self.c=delta_c
        
    def gradient(self,x,y):
        yp=self.top(x)

        d2a=np.mean((yp-y)*(x**2))
        d2b=np.mean((yp-y)*(x))
        d2c=np.mean((yp-y))
        return -d2a*self.lr,-d2b*self.lr,-d2c*self.lr
    
    def top(self,x):
        return self.a*(x**2) + self.b *x + self.c

# %%
a=var()

# %%
a.fit(x_mod,y_mod)

# %%
plt.scatter(x_mod,y_mod)
plt.scatter(x_mod,a.top(x_mod))
