# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.linspace(-10,10,100)

# %%
y=np.abs(a)

# %%
plt.plot(a,y)

# %%
plt.plot(a,a**2)

# %%
## differtiate gives slopes 
## slope of a line remain same

# %%
x=np.linspace(-10,10,100)

# %%
m,c=5,50

# %%
noise=np.random.randint(-10,10,100)

# %%
y=m*x +c + noise

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
class Linearcoustom:
    
    def __init__(self,lr=.01,max_step=10):
        self.lr=lr
        self.max_step=max_step
    
    def fit(self,x,y):
        self.coef_=np.random.random()       ### it is m 
        
        for i in range(self.max_step):
            self.gradient_decent(x,y)
        
    def gradient_decent(self,x,y):
        delta_coef=self.gradient(x,y)
        print(delta_coef)
        self.coef_+=delta_coef
    
    def gradient(self,x,y):
        yp=self.predict(x)
        d_e2m=np.mean((yp-y)*x)
        
        return -d_e2m * self.lr
    
    def predict(self,x):
        return x*self.coef_

# %%
top=Linearcoustom()

# %%
top.fit(x,y)
# Out:
# 1.4336655205161082
# 0.946122700407937
# 0.6243772703028808
# 0.4120469527924736
# 0.2719232415734841
# 0.17945102810910057
# 0.11842559430768938
# 0.07815291745557956
# 0.05157566269795831
# 0.03403646427205329

# %%
top.coef_
# Out:
# 4.928483693095817

# %%
plt.scatter(x,y)
plt.scatter(x,top.predict(x))

# %%
class Linearcoustom1:
    
    def __init__(self,lr=.01,max_step=10):
        self.lr=lr
        self.max_step=max_step
    
    def fit(self,x,y):
        self.coef_=np.random.random()       ### it is m 
        self.intercept_=np.random.random()
        
        for i in range(self.max_step):
            self.gradient_decent(x,y)
        
    def gradient_decent(self,x,y):
        delta_coef,delta_inter=self.gradient(x,y)
        print(delta_coef,delta_inter)
        self.coef_+=delta_coef
        self.intercept_+=delta_inter
        
    def gradient(self,x,y):
        yp=self.predict(x)
        d_e2m=np.mean((yp-y)*x)
        d_e2c=np.mean((yp-y))
        
        return -d_e2m * self.lr ,-d_e2c * self.lr
         
    
    def predict(self,x):
        return x*self.coef_+self.intercept_

# %%
top1=Linearcoustom1()

# %%
top.fit(x,y)
# Out:
# 1.6028274710334305
# 1.05775819637223
# 0.6980491800974988
# 0.4606654521855548
# 0.3040081771998949
# 0.20062492502080598
# 0.13239894041777078
# 0.08737438492216543
# 0.057661210251664534
# 0.03805251585631739

# %%
top1.fit(x,y)
# Out:
# 1.374905337348272 0.4840626541128976
# 0.9073449364318562 0.47922202757176857
# 0.598786557375905 0.474429807296051
# 0.3951588055410013 0.4696855092230904
# 0.26077820163648574 0.46498865413085955
# 0.1720960522584216 0.46033876758955095
# 0.1135718055308103 0.45573537991365526
# 0.07494974371730248 0.4511780261145188
# 0.04946178373263064 0.4466662458533736
# 0.03264144650368885 0.44219958339483995

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y)
plt.scatter(x,top1.predict(x))

# %%
import numpy as np

# %%
x=np.linspace(-100,100,100)
noise=np.random.randn(100)*1000
y=(x**2)+noise
x_mod=(x-np.mean(x))/np.std(x)
y_mod=-(y-np.mean(y))/(np.std(y))

# %%
plt.scatter(x_mod,y_mod)

# %%
#x=ax^2 + bx +c

# %%
class var:

    def __init__(self,lr=.01,maxstep=2000):
        self.lr=lr
        self.maxstep=maxstep
        
    def fit(self,x,y):
        self.a=np.random.random()
        self.b=np.random.random()
        self.c=np.random.random()
        
        for i in range(self.maxstep):
            self.grad(x,y)
            
    def grad(self,x,y):
        delta_a,delta_b,delta_c=self.gradient(x,y)
        self.a+=delta_a
        self.b+=delta_b
        self.c+=delta_c
        
    def gradient(self,x,y):
        yp=self.top(x)

        d2a=np.mean((yp-y)*(x**2))
        d2b=np.mean((yp-y)*(x))
        d2c=np.mean((yp-y))
        return -d2a*self.lr,-d2b*self.lr,-d2c*self.lr
    
    def top(self,x):
        return self.a*(x**2) + self.b *x + self.c

# %%
a=var()

# %%
a.fit(x_mod,y_mod)

# %%
plt.scatter(x_mod,y_mod)
plt.scatter(x_mod,a.top(x_mod))
