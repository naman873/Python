# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.linspace(-10,10,100)

# %%
y=np.abs(a)

# %%
plt.plot(a,y)

# %%
plt.plot(a,a**2)

# %%
## differtiate gives slopes 
## slope of a line remain same

# %%
x=np.linspace(-10,10,100)

# %%
m,c=5,50

# %%
noise=np.random.randint(-10,10,100)

# %%
y=m*x +c + noise

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
class Linearcoustom:
    
    def __init__(self,lr=.01,max_step=10):
        self.lr=lr
        self.max_step=max_step
    
    def fit(self,x,y):
        self.coef_=np.random.random()       ### it is m 
        
        for i in range(self.max_step):
            self.gradient_decent(x,y)
        
    def gradient_decent(self,x,y):
        delta_coef=self.gradient(x,y)
        print(delta_coef)
        self.coef_+=delta_coef
    
    def gradient(self,x,y):
        yp=self.predict(x)
        d_e2m=np.mean((yp-y)*x)
        
        return -d_e2m * self.lr
    
    def predict(self,x):
        return x*self.coef_

# %%
top=Linearcoustom()

# %%
top.fit(x,y)
# Out:
# 1.5283679293256487
# 1.0086199129556468
# 0.6656212220178678
# 0.439265183553879
# 0.2898854409985198
# 0.19130487015390546
# 0.12624833181873904
# 0.08331539742920152
# 0.054982551838799715
# 0.036284781684864584

# %%
top.coef_
# Out:
# 4.801239433562045

# %%
plt.scatter(x,y)
plt.scatter(x,top.predict(x))

# %%
class Linearcoustom1:
    
    def __init__(self,lr=.01,max_step=10):
        self.lr=lr
        self.max_step=max_step
    
    def fit(self,x,y):
        self.coef_=np.random.random()       ### it is m 
        self.intercept_=np.random.random()
        
        for i in range(self.max_step):
            self.gradient_decent(x,y)
        
    def gradient_decent(self,x,y):
        delta_coef,delta_inter=self.gradient(x,y)
        print(delta_coef,delta_inter)
        self.coef_+=delta_coef
        self.intercept_+=delta_inter
        
    def gradient(self,x,y):
        yp=self.predict(x)
        d_e2m=np.mean((yp-y)*x)
        d_e2c=np.mean((yp-y))
        
        return -d_e2m * self.lr ,-d_e2c * self.lr
         
    
    def predict(self,x):
        return x*self.coef_+self.intercept_

# %%
top1=Linearcoustom1()

# %%
top.fit(x,y)
# Out:
# 1.5741390233326953
# 1.0388257527717453
# 0.6855550422332057
# 0.4524201625512065
# 0.2985668412795841
# 0.19703400973332816
# 0.1300291781405129
# 0.0858105013991264
# 0.05662915243848083
# 0.03737142719845886

# %%
top1.fit(x,y)
# Out:
# 1.6006017915696464 0.4860816881992122
# 1.0562893978035377 0.4812208713172202
# 0.6970798719511561 0.476408662604048
# 0.46002577408224443 0.4716445759780074
# 0.3035860327276765 0.4669281302182273
# 0.20034633809637917 0.4622588489160451
# 0.13221509180771157 0.45763626042688466
# 0.08725305721990409 0.4530598978226158
# 0.0575811421383878 0.44852929884438975
# 0.03799967629334696 0.4440440058559457

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y)
plt.scatter(x,top1.predict(x))

# %%
import numpy as np

# %%
x=np.linspace(-100,100,100)
noise=np.random.randn(100)*1000
y=(x**2)+noise
x_mod=(x-np.mean(x))/np.std(x)
y_mod=-(y-np.mean(y))/(np.std(y))

# %%
plt.scatter(x_mod,y_mod)

# %%
#x=ax^2 + bx +c

# %%
class var:

    def __init__(self,lr=.01,maxstep=2000):
        self.lr=lr
        self.maxstep=maxstep
        
    def fit(self,x,y):
        self.a=np.random.random()
        self.b=np.random.random()
        self.c=np.random.random()
        
        for i in range(self.maxstep):
            self.grad(x,y)
            
    def grad(self,x,y):
        delta_a,delta_b,delta_c=self.gradient(x,y)
        self.a+=delta_a
        self.b+=delta_b
        self.c+=delta_c
        
    def gradient(self,x,y):
        yp=self.top(x)

        d2a=np.mean((yp-y)*(x**2))
        d2b=np.mean((yp-y)*(x))
        d2c=np.mean((yp-y))
        return -d2a*self.lr,-d2b*self.lr,-d2c*self.lr
    
    def top(self,x):
        return self.a*(x**2) + self.b *x + self.c

# %%
a=var()

# %%
a.fit(x_mod,y_mod)

# %%
plt.scatter(x_mod,y_mod)
plt.scatter(x_mod,a.top(x_mod))
