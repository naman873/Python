# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL

# %%
alpha=PIL.Image.open("cb.png")

# %%
alpha
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=454x189 at 0x2DCDFB06EF0>

# %%
type(alpha)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
cb=np.array(alpha)

# %%
cb.shape
# Out:
# (189, 454, 4)

# %%
panda=PIL.Image.open("panda.jpg")

# %%
panda
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=306x164 at 0x2DCDFAF9320>

# %%
pan=np.array(panda)

# %%
pan.size
# Out:
# 150552

# %%
pan.shape
# Out:
# (164, 306, 3)

# %%
cb1=cb[::4,::4]

# %%
cb1.shape
# Out:
# (48, 114, 4)

# %%
#cut=pan[:cb1.shape[0],-cb1.shape[1]:]
cut=pan[:-cb1.shape[0],:-cb1.shape[1]]

# %%
plt.imshow(cut)

# %%
for row in range(cb1.shape[0]):
    for col in range(cb1.shape[1]):
        if cb1[row,col,3]>100:
            cut[row,col]=cb1[row,col, :3]

# %%
plt.imshow(cut)

# %%
pan.shape
# Out:
# (164, 306, 3)

# %%
plt.imshow(pan)

# %%
img=PIL.Image.fromarray(pan)

# %%
s=open("editpanda.jpg","wt")
img.save(s)
