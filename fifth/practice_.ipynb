# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image
import PIL

# %%
panda=Image.open("panda.jpg")
cb=Image.open("cb.png")

# %%
panda_n=np.array(panda)
cb_n=np.array(cb)

# %%
cb_n=cb_n[::4,::4]

# %%
cb_n.shape
# Out:
# (24, 57, 4)

# %%
cut=panda_n[:cb_n.shape[0],cb_n.shape[1]:]

# %%
plt.imshow(cut)

# %%
for i in range(cb_n.shape[0]):
    for j in range(cb_n.shape[1]):
        if cb_n[i,j,3]>100:
            cut[i,j]=cb_n[i,j,:3]

# %%
plt.imshow(panda_n)

# %%
img=PIL.Image.fromarray(panda_n)

# %%
panda_n.shape
# Out:
# (164, 306, 3)

# %%
with open("prac_panda.jpeg","wt") as f:
    img.save(f)
