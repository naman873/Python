# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL

# %%
alpha=PIL.Image.open("cb.png")

# %%
alpha
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=454x189 at 0x1BF3CA897F0>

# %%
type(alpha)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
cb=np.array(alpha)

# %%
cb.shape
# Out:
# (189, 454, 4)

# %%
panda=PIL.Image.open("panda.jpg")

# %%
panda
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=306x164 at 0x1BF3FC30F98>

# %%
pan=np.array(panda)

# %%
pan.size
# Out:
# 150552

# %%
pan.shape
# Out:
# (164, 306, 3)

# %%
cb1=cb[::4,::4]

# %%
cb1.shape
# Out:
# (48, 114, 4)

# %%
x=50
y=50
w=cb1.shape[0]
z=cb1.shape[1]

# %%
cut=pan[x:x+w,y:y+z]

# %%
cut.shape
# Out:
# (48, 114, 3)

# %%
plt.imshow(cut)

# %%
for row in range(cb1.shape[0]):
    for col in range(cb1.shape[1]):
        if cb1[row,col,3]>100:
            cut[row,col]=cb1[row,col, :3]

# %%
plt.imshow(cut)

# %%
plt.imshow(pan)

# %%
img=PIL.Image.fromarray(pan)

# %%
s=open("editpanda1.jpg","wt")
img.save(s)
