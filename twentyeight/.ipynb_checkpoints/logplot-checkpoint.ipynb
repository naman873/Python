# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(-10,10,100)

# %%
y=np.sin(x)+3

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.plot(x,np.log(y))

# %%
x=np.linspace(-1000,1000,1000)

# %%
plt.plot(1/(1+np.exp(-x)))
# Out:
# C:\Users\Naman\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in exp
#   """Entry point for launching an IPython kernel.
